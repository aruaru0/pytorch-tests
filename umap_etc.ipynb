# %% [markdown]
# <a href="https://colab.research.google.com/github/aruaru0/pytorch-tests/blob/main/umap_etc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install umap-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000,
                           n_features=20,
                           n_informative = 5,
                           n_classes=3,
                           n_clusters_per_class = 1,
                           random_state=42)
df = pd.DataFrame(X)
df['target'] = y
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.170010 -1.386743 -0.560724  0.955938 -0.287082 -1.041887  0.287920
# 1   -1.168178 -1.510816 -1.082722  1.667257  1.650573 -0.629212  2.135587
# 2   -1.197532 -1.437999  0.221824 -0.198569 -0.662691  0.086761  1.274653
# 3    0.096009 -1.890765 -0.487648 -0.575186  0.226304 -0.100173  0.508012
# 4   -2.355703  0.080629  2.112706 -0.093609 -1.391983 -0.879717 -0.751167
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  1.011097 -1.072729 -0.257928 -1.443115 -1.197167  1.672990  0.225842
# 996  0.887309  1.520612 -1.082522 -0.752719 -0.759652 -1.023734  0.444875
# 997  0.018796 -1.844501 -0.880495  1.068705  1.160048  0.445397  0.548879
# 998 -0.499202  0.215334  0.831149 -0.573703  0.280928  0.808989  0.316274
# 999 -1.755506 -0.863676  0.342278 -0.795655 -0.851180  0.665335 -1.311549
#
#             7         8         9  ...        11        12        13  \
# ...

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
# PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.show()

# %%
# t-SNE
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# %%
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y)
plt.show()

# %%
# UMAP
import umap

umap = umap.UMAP(n_components=2, random_state=42)
X_umap = umap.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
plt.scatter(X_umap[:, 0], X_umap[:, 1], c=y)
plt.show()

# %%
df.describe()
# Out:
#                  0            1            2            3            4  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.024823    -0.936568     0.304047    -0.019426    -0.009256
# std       0.993421     1.530310     1.434098     1.025770     0.996720
# min      -3.375579    -7.082080    -3.765331    -3.250333    -3.329504
# 25%      -0.702266    -1.719205    -0.796936    -0.711906    -0.722264
# 50%       0.011472    -0.861614     0.330017    -0.022603     0.015317
# 75%       0.647201     0.000809     1.233546     0.648948     0.680028
# max       3.040687     5.000682     4.837464     3.157771     3.117681
#
#                  5            6            7            8            9  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean      0.015175     0.014890     0.016317     0.014735     0.308847  ...
# std       0.996029     1.030976     0.971882     0.975070     1.352846  ...
# ...

# %%
import scipy as sp
df = sp.stats.zscore(df)
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   3.552714e-18  1.421085e-17 -8.881784e-19  3.907985e-17 -1.598721e-17
# std    1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00
# min   -3.374635e+00 -4.017870e+00 -2.839007e+00 -3.151316e+00 -3.332843e+00
# 25%   -6.822714e-01 -5.116799e-01 -7.681022e-01 -6.754210e-01 -7.157126e-01
# 50%    3.655346e-02  4.900386e-02  1.811800e-02 -3.099291e-03  2.466591e-02
# 75%    6.768125e-01  6.128472e-01  6.484660e-01  6.519087e-01  6.918985e-01
# max    3.087355e+00  3.881710e+00  3.162745e+00  3.098928e+00  3.138798e+00
#
#                   5             6             7             8             9  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   1.243450e-17  8.881784e-18 -1.065814e-17  2.131628e-17 -1.243450e-17
# ...

# %%
Xzero = sp.stats.zscore(X)
Xzero[:, 0] *= 100

# %%
import umap

umap = umap.UMAP(n_components=2, random_state=42)
X_umap = umap.fit_transform(Xzero)

plt.scatter(X_umap[:, 0], X_umap[:, 1], c=y)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(Xzero)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.show()

# %%
# t-SNE
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# %%
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y)
plt.show()
