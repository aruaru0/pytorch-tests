# %% [markdown]
# <a href="https://colab.research.google.com/github/aruaru0/pytorch-tests/blob/main/tqdm_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tqdm import tqdm
import time

for i in tqdm(range(100)):
    time.sleep(0.1)
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.83it/s]

# %%
from tqdm import tqdm
import time

x = ['a', 'b', 'c', 'd', 'e', 'f']
for e in tqdm(x):
    time.sleep(1)
# Out:
# 100%|██████████| 6/6 [00:06<00:00,  1.00s/it]

# %%
from tqdm import tqdm
import time

with tqdm(total = 100) as pbar:
  for i in range(100):
    time.sleep(0.1)
    pbar.update()
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.82it/s]

# %%
from tqdm import tqdm
import time

with tqdm(total = 100) as pbar:
  for i in range(10):
    time.sleep(0.1)
    pbar.update(10)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 98.42it/s]

# %%
from tqdm import tqdm
import time

for i in tqdm(range(100), desc="SAMPLE"):
    time.sleep(0.1)
# Out:
# SAMPLE: 100%|██████████| 100/100 [00:10<00:00,  9.84it/s]

# %%
from tqdm import tqdm
import time

with tqdm(total = 100) as pbar:
  pbar.set_description("SAMPLE") # 説明文を追加
  for i in range(100):
    time.sleep(0.1)
    pbar.update()
# Out:
# SAMPLE: 100%|██████████| 100/100 [00:10<00:00,  9.81it/s]

# %%
from tqdm import tqdm
import time

with tqdm(total = 100) as pbar:
  for i in range(10):
    pbar.set_description(f"[{i}]")
    for j in range(10):
      time.sleep(0.1)
      pbar.update()
# Out:
# [9]: 100%|██████████| 100/100 [00:10<00:00,  9.84it/s]

# %%
from tqdm import tqdm
import time
import random

with tqdm(total = 100) as pbar:
  for i in range(100):
    time.sleep(0.1)
    pbar.set_postfix({"val": random.random()})
    pbar.update()
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.67it/s, val=0.709]

# %%
from tqdm import tqdm
import time
import random

with tqdm(total = 100) as pbar:
  for i in range(100):
    time.sleep(0.1)
    pbar.set_postfix_str(f"val:{random.random()}")
    pbar.update()
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.68it/s, val:0.41087129503640296]

# %%
from tqdm.notebook import tqdm
import time
import random

with tqdm(total = 100) as pbar:
  for i in range(100):
    time.sleep(0.1)
    r = random.random()
    if r > 0.8:
      pbar.write(f"Update r = {r}")
    pbar.update()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Update r = 0.9599128930420796
# Update r = 0.8295103509529336
# Update r = 0.8485531902723298
# Update r = 0.9202279369877494
# Update r = 0.9059442138498264
# Update r = 0.8391823807032976
# Update r = 0.820399189386768
# Update r = 0.9801115813006234
# Update r = 0.8157078209815567
# Update r = 0.8610107982339573
# Update r = 0.9641479350606893
# Update r = 0.8887234842202539
# Update r = 0.9420266428614417
# Update r = 0.9866970486787917
# Update r = 0.9767637057267942
# Update r = 0.972862648539425
# Update r = 0.8616012090195709
# Update r = 0.8812927110894696
# Update r = 0.8916032828854129
# Update r = 0.9321434622289524
# Update r = 0.9616557262636632
# Update r = 0.856943234100029
# Update r = 0.8693767147221892
# Update r = 0.9019525639445565
# Update r = 0.9370184044420895

# %%
from tqdm.notebook import tqdm
import time
import random

for i in tqdm(range(5), desc="LOOP1"):
    for j in tqdm(range(100), desc="Loop2", leave=False):
         time.sleep(0.01)
# Out:
# LOOP1:   0%|          | 0/5 [00:00<?, ?it/s]
# Loop2:   0%|          | 0/100 [00:00<?, ?it/s]
# Loop2:   0%|          | 0/100 [00:00<?, ?it/s]
# Loop2:   0%|          | 0/100 [00:00<?, ?it/s]
# Loop2:   0%|          | 0/100 [00:00<?, ?it/s]
# Loop2:   0%|          | 0/100 [00:00<?, ?it/s]
